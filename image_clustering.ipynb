# %% [markdown]
# # Image clustering with custom K-Means and DBSCAN
#
# This notebook is a thin exploratory interface. The tested implementations live in `algorithms.py`, and the reproducible experiment lives in `run_clustering.py`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from run_clustering import run_experiment

# %%
metrics = run_experiment()
metrics

# %%
from IPython.display import Image, display
display(Image(filename=ROOT / 'outputs' / 'comparison.png'))
